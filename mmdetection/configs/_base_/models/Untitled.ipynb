# %%
import pandas as pd

def list_chunk(lst, n):
    return [lst[i:i+n] for i in range(0, len(lst), n)]

# %%
df1 = pd.read_csv('/opt/ml/detection/ensemble/swint_cascade_rcnn.csv')
df1
# Out:
#                                        PredictionString       image_id
# 0     0 0.12492337 168.7745 427.26825 200.05522 452....  test/0000.jpg
# 1     0 0.4094736 638.17615 645.37805 686.53796 835....  test/0001.jpg
# 2     0 0.47135228 882.4818 464.70532 1022.06067 627...  test/0002.jpg
# 3     9 0.9960171 170.14467 274.95535 907.7722 811.5...  test/0003.jpg
# 4     0 0.7451359 419.07297 378.4336 699.7894 564.89...  test/0004.jpg
# ...                                                 ...            ...
# 4866  0 0.80568784 293.115 352.02246 670.05914 691.6...  test/4866.jpg
# 4867  0 0.7182442 631.621 665.33984 772.9795 720.998...  test/4867.jpg
# 4868  0 0.07002562 542.9192 536.6102 709.4158 802.40...  test/4868.jpg
# 4869  0 0.9982556 4.5619407 208.81384 1010.9939 932....  test/4869.jpg
# 4870  0 0.20791864 240.40404 821.87256 291.3221 853....  test/4870.jpg
#
# [4871 rows x 2 columns]

# %%
a = df1['PredictionString']

# %%
boxes_list = [[],[]]
scores_list = [[],[]]
labels_list = [[], []]
weights = [2, 1]

iou_thr = 0.5
skip_box_thr = 0.0001
sigma = 0.1
               


for i in a:
    sub = i.split()
    chunked = list_chunk(sub,6)
    
    for chunk in chunked:
        labels_list.
        

#list_chunked
# Out:
# [['0', '0.12492337', '168.7745', '427.26825', '200.05522', '452.48236'], ['0', '0.062261418', '486.8589', '591.4661', '574.98846', '650.40466'], ['0', '0.05273003', '327.54004', '638.56287', '353.6308', '682.4928'], ['1', '0.98519135', '564.02374', '104.90172', '764.7546', '361.82727'], ['1', '0.55563724', '635.4535', '140.78123', '754.21313', '345.54657'], ['1', '0.34767863', '429.646', '451.9072', '569.09705', '680.0582'], ['1', '0.29076958', '163.07794', '367.31995', '251.32805', '446.24347'], ['1', '0.2603144', '564.41364', '126.16553', '674.961', '358.82135'], ['1', '0.20104635', '640.64636', '255.36584', '735.51807', '343.60864'], ['1', '0.19449458', '327.54004', '638.56287', '353.6308', '682.4928'], ['1', '0.18739024', '670.7084', '257.64294', '730.1291', '318.9596'], ['1', '0.17823367', '244.79594', '681.7177', '300.73456', '749.4275'], ['1', '0.1708357', '469.2601', '554.3368', '559.38904', '600.47235'], ['1', '0.15351516', '243.72348', '408.29303', '293.6126', '476.83435'], ['1', '0.13030872', '385.60565', '681.2432', '425.05222', '719.38794'], ['1', '0.12394058', '168.7745', '427.26825', '200.05522', '452.48236'], ['1', '0.10344221', '504.5478', '100.547226', '837.1553', '503.04538'], ['1', '0.089774966', '496.23798', '116.49136', '591.92523', '223.42003'], ['1', '0.07598909', '485.17236', '177.51517', '735.9181', '360.8004'], ['1', '0.07352865', '486.8589', '591.4661', '574.98846', '650.40466'], ['1', '0.073090784', '468.153', '570.3465', '568.50946', '677.8822'], ['1', '0.05690509', '548.41187', '345.89316', '717.0685', '604.1931'], ['1', '0.05356607', '130.55309', '355.86755', '254.2263', '481.22345'], ['2', '0.13582182', '328.2835', '638.7569', '352.64124', '682.87054'], ['2', '0.067927554', '671.3259', '257.48636', '730.2319', '318.80786'], ['5', '0.6364886', '334.78857', '632.58704', '398.23584', '723.0627'], ['5', '0.43722528', '332.35306', '666.6696', '470.72946', '742.2253'], ['5', '0.42796192', '244.67099', '682.36255', '300.82312', '749.2699'], ['5', '0.27646023', '393.97192', '620.622', '451.1623', '689.5619'], ['5', '0.17643127', '354.17767', '676.95276', '436.67563', '724.3637'], ['5', '0.16805916', '385.60565', '681.2432', '425.05222', '719.38794'], ['5', '0.16058072', '498.4791', '597.16064', '587.99255', '650.7156'], ['5', '0.13044101', '323.2148', '569.2309', '380.07492', '620.4655'], ['5', '0.12818675', '337.5179', '547.8087', '456.78485', '726.0541'], ['5', '0.119778514', '350.85394', '683.5072', '395.9658', '724.89374'], ['5', '0.11871343', '415.16345', '613.01807', '446.60736', '683.18604'], ['5', '0.114915185', '500.24854', '596.1108', '551.5976', '641.41644'], ['5', '0.10726284', '389.43002', '623.7515', '459.24985', '731.9905'], ['5', '0.10431434', '476.26318', '582.86707', '573.5403', '669.8187'], ['5', '0.08707961', '325.14114', '638.4162', '379.85455', '691.6411'], ['5', '0.08448484', '328.8944', '639.3613', '353.9427', '681.5844'], ['5', '0.07277729', '377.91696', '660.77216', '449.96802', '724.5458'], ['5', '0.07158043', '323.1687', '684.5944', '396.69626', '746.9597'], ['5', '0.07000406', '670.7084', '257.64294', '730.1291', '318.9596'], ['5', '0.0683084', '323.70392', '708.7407', '453.80222', '748.93176'], ['5', '0.06500095', '410.7071', '552.7988', '453.04828', '685.0322'], ['5', '0.061293088', '418.94824', '545.90845', '476.38446', '671.51697'], ['5', '0.05660772', '329.88498', '686.8762', '365.9615', '743.8188'], ['5', '0.055131655', '360.45673', '550.3319', '444.14062', '627.64276'], ['5', '0.054799013', '357.34152', '628.4949', '419.27924', '729.82733'], ['5', '0.051975295', '406.01813', '656.55475', '471.93884', '739.86426'], ['6', '0.399136', '244.66177', '682.4943', '300.8446', '749.21893'], ['7', '0.9990141', '218.07455', '55.602276', '455.62607', '484.25458'], ['7', '0.99833226', '601.2087', '482.87708', '948.96423', '1024.0'], ['7', '0.9982175', '119.22235', '416.8209', '324.19864', '709.04065'], ['7', '0.9880442', '451.2937', '597.96967', '654.5783', '873.7109'], ['7', '0. ...

# %%
from ensemble_boxes import *

boxes_list = [[
    [0.00, 0.51, 0.81, 0.91],
    [0.10, 0.31, 0.71, 0.61],
    [0.01, 0.32, 0.83, 0.93],
    [0.02, 0.53, 0.11, 0.94],
    [0.03, 0.24, 0.12, 0.35],
],[
    [0.04, 0.56, 0.84, 0.92],
    [0.12, 0.33, 0.72, 0.64],
    [0.38, 0.66, 0.79, 0.95],
    [0.08, 0.49, 0.21, 0.89],
]]
scores_list = [[0.9, 0.8, 0.2, 0.4, 0.7], [0.5, 0.8, 0.7, 0.3]]
labels_list = [[0, 1, 0, 1, 1], [1, 1, 1, 0]]
weights = [2, 1]

iou_thr = 0.5
skip_box_thr = 0.0001
sigma = 0.1

boxes, scores, labels = nms(boxes_list, scores_list, labels_list, weights=weights, iou_thr=iou_thr)
boxes, scores, labels = soft_nms(boxes_list, scores_list, labels_list, weights=weights, iou_thr=iou_thr, sigma=sigma, thresh=skip_box_thr)
boxes, scores, labels = non_maximum_weighted(boxes_list, scores_list, labels_list, weights=weights, iou_thr=iou_thr, skip_box_thr=skip_box_thr)
boxes, scores, labels = weighted_boxes_fusion(boxes_list, scores_list, labels_list, weights=weights, iou_thr=iou_thr, skip_box_thr=skip_box_thr)

# %%
len(labels)
# Out:
# 7
